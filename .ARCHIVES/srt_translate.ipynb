# %%
x = 'toto.mkv'
x.endswith(('ka','kv'))
# Out:
# True

# %%
x = str('toto & €'.encode('ascii','ignore'))
type(x), x
# Out:
# (str, "b'toto & '")

# %%
from os import listdir

from lib_srt import srt
from lib_translateLocally import translateLocally

# %%
# Functions
def run_translate(definition):
    my_srt = srt()
    my_tr = translateLocally() # preconfigured with binary and model
    if 'sub_in' not in definition:
        return -1
    if 'sub_out'  not in definition:
        return -2
    sub_len = len(definition['sub_in'])
    if sub_len != len(definition['sub_out']):
        return -3
    for cpt in range(0, sub_len):
        left = definition['sub_in'][cpt]
        right = definition['sub_out'][cpt]
        left_html = left[:-3] + "en.html"
        right_html = left[:-3] + "fr.html"
        my_srt.srt_to_html(left, left_html)
        my_tr.translate(left_html, right_html)
        my_srt.html_to_srt(right_html, right)
        return

worksheet = {
    # Lists for extraction
    'video_in': [],
    # Lists for translations
    'sub_in': [r"D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.srt"],
    'sub_out': [r"D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.fr.srt"]
    }

# Ajouter  : les sous-titres extraits à la liste dans worksheet
run_translate(worksheet)

# Job done
print("Complete")
# Out:
# srt to html 'D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.srt' > 'D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.en.html'
# Ligne 1: ^﻿1^
# Ligne 2: ^00:01:28,546 --> 00:01:30,674^
# Ligne 3: ^Life Foundation Control, this is LF1.^
# Warning : blank line detected and missing data : ID=False TIMES=True TEXT=True LINE=4
# Ligne 4: ^^
# Will run /usr/bin/translateLocally -m en-fr-tiny --html --input "D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.en.html" --output "D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.fr.html"
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 31
#      22 worksheet = {
#      23     # Lists for extraction
#      24     'video_in': [],
#    (...)
#      27     'sub_out': [r"D:\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.fr.srt"]
#      28     }
#      30 # Ajouter  : les sous-titres extraits à la liste dans worksheet
# ---> 31 run_translate(worksheet)
#      33 # Job done
#      34 print("Complete")
#
# Cell In[2], line 19, in run_translate(definition)
#      17 my_srt.srt_to_html(left, left_html)
#      18 my_tr.translate(left_html, right_html)
# ---> 19 my_srt.html_to_srt(right_html, right)
#      20 return
#
# File d:\Oliv\GITHUB\srt_translate\lib_srt.py:212, in srt.html_to_srt(self, input_html, output_srt)
#     210 parser.init()
#     211 translated = None
# --> 212 with open(input_html, "r", encoding="utf-8") as fin:
#     213     translated = fin.read()
#     214 parser.feed(translated)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\Venom.2018.1080p.UHD.BluRay.x265.HDR.DD5.1-Pahe.in.fr.html'
